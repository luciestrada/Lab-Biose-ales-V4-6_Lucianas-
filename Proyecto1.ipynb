# %% [markdown]
# <a href="https://colab.research.google.com/github/luciestrada/Lab-Biose-ales-V4-6_Lucianas-/blob/main/Proyecto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CONSULTA**
# **1.**  historia, uso y proyectos futuros relacionados con Interfaz Cerebro Computador
#
# **2**.  actividad cerebral registrada por EEG durante movimientos e imaginación
# de movimiento de las manos y cómo se hace su análisis en sistemas BCI: Electrodos, ritmos cerebrales de interés
#
# **3.** Consultar y discutir los flujos de procesamiento propuestos para estos tipos de proyectos y
# que se puedan realizar en el marco del curso

# %% [markdown]
# info organziada todo compelo listo el pollo

# %% [markdown]
# blaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
# cdogio para recolecta datos
